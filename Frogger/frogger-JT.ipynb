# %%
import pandas as pd
import gymnasium as gym
import os
from ale_py import ALEInterface, roms
import time
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
env = gym.make("ALE/Frogger-v5", render_mode='human')

initial_state = env.reset()
while True:
    env.render()


    # Take a step (0: LEFT, 1: DOWN, 2: RIGHT, 3: UP)
    action = env.action_space.sample()
    new_state, reward, terminated, truncated, info = env.step(action)
    print(action)

    env.render()

time.sleep(5)

env.reset()
env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3228\1639297649.py in <module>
#       1 import pandas as pd
# ----> 2 import gymnasium as gym
#       3 import os
#       4 from ale_py import ALEInterface, roms
#       5 import time
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
env = gym.make("ALE/Frogger-v5", render_mode='rgb_array')
initial_state = env.reset()

# %%
screenshot=env.render()

# %%
plt.imshow(screenshot)
plt.axis("off")
plt.show()

# %%
def gary(image):
    gar=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
    crap=gar[12:-30, 7:-7]
    resized = cv2.resize(crap, (84, 110), interpolation=cv2.INTER_AREA)
    return resized

# %%
pros=gary(screenshot)

# %%
plt.imshow(pros,cmap='gray')
plt.axis("off")
plt.show()
